# %% [markdown]
# https://github.com/keras-team/keras-tuner

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import kerastuner as kt
from kerastuner.applications import HyperResNet, HyperXception
from kerastuner.tuners import Hyperband, BayesianOptimization, RandomSearch

# %%
data = tfds.load('cifar10')
train_ds, test_ds = data['train'], data['test']
def standardize_record(record):
  return tf.cast(record['image'], tf.float32) / 255., record['label']
train_ds = train_ds.map(standardize_record).cache().batch(64).shuffle(10000)
test_ds = test_ds.map(standardize_record).cache().batch(64)

# %%
hypermodel = HyperResNet(input_shape=(32,32,3),classes=10)
tuner1 = Hyperband(
    hypermodel,
    objective='val_accuracy',
    max_epochs=10,
    directory='hyperband_test',
    project_name='hello_world')
tuner1.search(train_ds,
             validation_data=test_ds,
             epochs=10,
             callbacks=[tf.keras.callbacks.EarlyStopping(patience=1)])
# Out:
# INFO:tensorflow:Reloading Oracle from existing project hyperband_test\hello_world\oracle.json
# Epoch 1/2
#  - 98s 126ms/step - loss: 194190.0137 - accuracy: 0.0354 - val_loss: 448229.2890 - val_accuracy: 0.0000e+00
# Epoch 2/2
#  - 76s 97ms/step - loss: 463614.7989 - accuracy: 0.0536 - val_loss: 665713.2504 - val_accuracy: 0.0000e+00
# Epoch 1/2
#  - 76s 97ms/step - loss: 536.8530 - accuracy: 0.2167 - val_loss: 4768.1749 - val_accuracy: 0.1971
# Epoch 2/2
#  - 59s 75ms/step - loss: 1567.9716 - accuracy: 0.1808 - val_loss: 1023.0698 - val_accuracy: 0.3777
# Epoch 1/2
#  - 42s 54ms/step - loss: 250.1561 - accuracy: 3.2000e-04 - val_loss: 188.8453 - val_accuracy: 0.0050
# Epoch 2/2
#  - 35s 44ms/step - loss: 210.7641 - accuracy: 2.0000e-05 - val_loss: 178.2296 - val_accuracy: 0.0000e+00
# Epoch 1/2
#  - 61s 79ms/step - loss: 39559.4702 - accuracy: 0.1065 - val_loss: 4247.4800 - val_accuracy: 0.0000e+00
# Epoch 2/2
#  - 52s 67ms/step - loss: 103297.4884 - accuracy: 0.0992 - val_loss: 72557.4686 - val_accuracy: 0.0000e+00
# Epoch 1/2
#  - 76s 97ms/step - loss: nan - accuracy: 0.9809 - val_loss: nan - val_accuracy: 1.0000
# Epoch 1/2
#  - 47s 61ms/step - loss: 2830523174895627247915368448.0000 - accuracy: 0.0939 - val_loss: 103.5613 - val_accuracy: 0.0000e+00
# Epoch 2/2
#  - 37s 48ms/step - loss: 103.6163 - accuracy: 0.0000e+00 - val_loss: 103.5613 - val_accuracy: 0.0000e+00
# Epoch 1/2
#  - 122s 155ms/step - loss: 144002.9942 - accuracy: 0.0969 - val_loss: 64386.6355 - val_accuracy: 0.0000e+00
# Epoch 2/2
#  - 189s 242ms/step - loss: 422459.0022 - accuracy: 0.0923 - val_loss: 721289.5191 - val_accuracy: 0.0000e+00
# Epoch 1/2
#  - 33s 286ms/step - loss: 1565216220506912.5000 - accuracy: 0.0646
# INFO:tensorflow:Reloading Oracle from existing project hyperband_test\hello_world\oracle.json
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\keras\callbacks.py:1261: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 368804a11b64659338319a6d9f7d8891</span>
# <span style="color:cyan"> |-Score: 0.0</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv3_depth: 8</span>
# <span style="color:blue"> |-conv4_depth: 23</span>
# <span style="color:cyan"> |-learning_rate: 0.1</span>
# <span style="color:blue"> |-optimizer: adam</span>
# <span style="color:cyan"> |-pooling: avg</span>
# <span style="color:blue"> |-tuner/bracket: 2</span>
# <span style="color:cyan"> |-tuner/epochs: 2</span>
# <span style="color:blue"> |-tuner/initial_epoch: 0</span>
# <span style="color:cyan"> |-tuner/round: 0</span>
# <span style="color:blue"> |-version: next</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 90ae277bbdab17c33ac7546b02997ac0</span>
# <span style="color:cyan"> |-Score: 0.37770000100135803</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv3_depth: 8</span>
# <span style="color:blue"> |-conv4_depth: 23</span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-optimizer: adam</span>
# <span style="color:cyan"> |-pooling: avg</span>
# <span style="color:blue"> |-tuner/bracket: 2</span>
# <span style="color:cyan"> |-tuner/epochs: 2</span>
# <span style="color:blue"> |-tuner/initial_epoch: 0</span>
# <span style="color:cyan"> |-tuner/round: 0</span>
# <span style="color:blue"> |-version: v2</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 4ebabcf246a8fec42c502de66bda1fb1</span>
# <span style="color:cyan"> |-Score: 0.004999999888241291</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv3_depth: 8</span>
# <span style="color:blue"> |-conv4_depth: 6</span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-optimizer: adam</span>
# <span style="color:cyan"> |-pooling: max</span>
# <span style="color:blue"> |-tuner/bracket: 2</span>
# <span style="color:cyan"> |-tuner/epochs: 2</span>
# <span style="color:blue"> |-tuner/initial_epoch: 0</span>
# <span style="color:cyan"> |-tuner/round: 0</span>
# <span style="color:blue"> |-version: v1</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: a08420f0b25013440d0b38e0748e1303</span>
# <span style="color:cyan"> |-Score: 0.0</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv3_depth: 4</span>
# <span style="color:blue"> |-conv4_depth: 23</span>
# <span style="color:cyan"> |-learning_rate: 0.1</span>
# <span style="color:blue"> |-optimizer: adam</span>
# <span style="color:cyan"> |-pooling: max</span>
# <span style="color:blue"> |-tuner/bracket: 2</span>
# <span style="color:cyan"> |-tuner/epochs: 2</span>
# <span style="color:blue"> |-tuner/initial_epoch: 0</span>
# <span style="color:cyan"> |-tuner/round: 0</span>
# <span style="color:blue"> |-version: v2</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 2e0d4dd846cf7def51f9d3e4e24ef3ac</span>
# <span style="color:cyan"> |-Score: 1.0</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv3_depth: 4</span>
# <span style="color:blue"> |-conv4_depth: 23</span>
# <span style="color:cyan"> |-learning_rate: 0.1</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-pooling: max</span>
# <span style="color:blue"> |-tuner/bracket: 2</span>
# <span style="color:cyan"> |-tuner/epochs: 2</span>
# <span style="color:blue"> |-tuner/initial_epoch: 0</span>
# <span style="color:cyan"> |-tuner/round: 0</span>
# <span style="color:blue"> |-version: next</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 758b032e1f56d41b6e6c666bc7e2d83e</span>
# <span style="color:cyan"> |-Score: 0.0</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv3_depth: 8</span>
# <span style="color:blue"> |-conv4_depth: 6</span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-pooling: avg</span>
# <span style="color:blue"> |-tuner/bracket: 2</span>
# <span style="color:cyan"> |-tuner/epochs: 2</span>
# <span style="color:blue"> |-tuner/initial_epoch: 0</span>
# <span style="color:cyan"> |-tuner/round: 0</span>
# <span style="color:blue"> |-version: next</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: a0d5155f67897ad91669ce72a5d50271</span>
# <span style="color:cyan"> |-Score: 0.0</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv3_depth: 8</span>
# <span style="color:blue"> |-conv4_depth: 36</span>
# <span style="color:cyan"> |-learning_rate: 0.1</span>
# <span style="color:blue"> |-optimizer: rmsprop</span>
# <span style="color:cyan"> |-pooling: max</span>
# <span style="color:blue"> |-tuner/bracket: 2</span>
# <span style="color:cyan"> |-tuner/epochs: 2</span>
# <span style="color:blue"> |-tuner/initial_epoch: 0</span>
# <span style="color:cyan"> |-tuner/round: 0</span>
# <span style="color:blue"> |-version: v1</span>

# %%
def build_model(hp):
  inputs = tf.keras.Input(shape=(32, 32, 3))
  x = inputs
  for i in range(hp.Int('conv_blocks', 3, 5, default=3)):
    filters = hp.Int('filters_' + str(i), 32, 256, step=32)
    for _ in range(2):
      x = tf.keras.layers.Convolution2D(
        filters, kernel_size=(3, 3), padding='same')(x)
      x = tf.keras.layers.BatchNormalization()(x)
      x = tf.keras.layers.ReLU()(x)
    if hp.Choice('pooling_' + str(i), ['avg', 'max']) == 'max':
      x = tf.keras.layers.MaxPool2D()(x)
    else:
      x = tf.keras.layers.AvgPool2D()(x)
  x = tf.keras.layers.GlobalAvgPool2D()(x)
  x = tf.keras.layers.Dense(
      hp.Int('hidden_size', 30, 100, step=10, default=50),
      activation='relu')(x)
  x = tf.keras.layers.Dropout(
      hp.Float('dropout', 0, 0.5, step=0.1, default=0.5))(x)
  outputs = tf.keras.layers.Dense(10, activation='softmax')(x)

  model = tf.keras.Model(inputs, outputs)
  model.compile(
    optimizer=tf.keras.optimizers.Adam(
      hp.Float('learning_rate', 1e-4, 1e-2, sampling='log')),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])
  return model

# %%
tuner2 = kt.Hyperband(
    build_model,
    objective='val_accuracy',
    max_epochs=10,
    hyperband_iterations=2)
tuner2.search(train_ds,
             validation_data=test_ds,
             epochs=10,
             callbacks=[tf.keras.callbacks.EarlyStopping(patience=1)])
# Out:
# Epoch 1/2
#  - 20s 26ms/step - loss: 1.3070 - accuracy: 0.5247 - val_loss: 1.5032 - val_accuracy: 0.5176
# Epoch 2/2
#  - 15s 19ms/step - loss: 0.8170 - accuracy: 0.7196 - val_loss: 0.9199 - val_accuracy: 0.6831
# Epoch 1/2
#  - 24s 30ms/step - loss: 1.3973 - accuracy: 0.5034 - val_loss: 1.0808 - val_accuracy: 0.6198
# Epoch 2/2
#  - 21s 27ms/step - loss: 0.9224 - accuracy: 0.6814 - val_loss: 1.0516 - val_accuracy: 0.6115
# Epoch 1/2
#  - 29s 37ms/step - loss: 1.6610 - accuracy: 0.3750 - val_loss: 1.7038 - val_accuracy: 0.4118
# Epoch 2/2
#  - 29s 37ms/step - loss: 1.2267 - accuracy: 0.5585 - val_loss: 1.0736 - val_accuracy: 0.6173
# Epoch 1/2
#  - 13s 17ms/step - loss: 1.5002 - accuracy: 0.4624 - val_loss: 1.3213 - val_accuracy: 0.5311
# Epoch 2/2
#  - 11s 14ms/step - loss: 1.0454 - accuracy: 0.6387 - val_loss: 1.0682 - val_accuracy: 0.6330
# Epoch 1/2
#  - 12s 15ms/step - loss: 1.2548 - accuracy: 0.5537 - val_loss: 1.1213 - val_accuracy: 0.6099
# Epoch 2/2
#  - 9s 11ms/step - loss: 0.7838 - accuracy: 0.7265 - val_loss: 1.1372 - val_accuracy: 0.6203
# Epoch 1/2
#  - 14s 17ms/step - loss: 1.3373 - accuracy: 0.5211 - val_loss: 1.2081 - val_accuracy: 0.5656
# Epoch 2/2
#  - 11s 14ms/step - loss: 0.9255 - accuracy: 0.6796 - val_loss: 0.8668 - val_accuracy: 0.6939
# Epoch 1/2
#  - 25s 32ms/step - loss: 1.3591 - accuracy: 0.5149 - val_loss: 1.4757 - val_accuracy: 0.5091
# Epoch 2/2
#  - 22s 28ms/step - loss: 0.9018 - accuracy: 0.6902 - val_loss: 0.9679 - val_accuracy: 0.6642
# Epoch 1/2
#  - 19s 24ms/step - loss: 1.7241 - accuracy: 0.3189 - val_loss: 1.5332 - val_accuracy: 0.4209
# Epoch 2/2
#  - 15s 19ms/step - loss: 1.3402 - accuracy: 0.4999 - val_loss: 1.4560 - val_accuracy: 0.5186
# Epoch 1/2
#  - 12s 16ms/step - loss: 1.7453 - accuracy: 0.3326 - val_loss: 1.9146 - val_accuracy: 0.3238
# Epoch 2/2
#  - 10s 13ms/step - loss: 1.3757 - accuracy: 0.4950 - val_loss: 1.2905 - val_accuracy: 0.5285
# Epoch 1/2
#  - 20s 25ms/step - loss: 1.4048 - accuracy: 0.4942 - val_loss: 1.1393 - val_accuracy: 0.5896
# Epoch 2/2
#  - 18s 22ms/step - loss: 0.9344 - accuracy: 0.6726 - val_loss: 0.8526 - val_accuracy: 0.7012
# Epoch 1/2
#  - 24s 30ms/step - loss: 1.6251 - accuracy: 0.3913 - val_loss: 1.5277 - val_accuracy: 0.4401
# Epoch 2/2
#  - ETA: 10s - loss: 1.2275 - accuracy: 0.5587WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: b0476fbafcef8a87646df649e11efde7</span>
# <span style="color:cyan"> |-Score: 0.6830999851226807</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_blocks: 4</span>
# <span style="color:blue"> |-dropout: 0.1</span>
# <span style="color:cyan"> |-filters_0: 128</span>
# <span style="color:blue"> |-filters_1: 160</span>
# <span style="color:cyan"> |-filters_2: 128</span>
# <span style="color:blue"> |-filters_3: 32</span>
# <span style="color:cyan"> |-hidden_size: 40</span>
# <span style="color:blue"> |-learning_rate: 0.0013315024194091836</span>
# <span style="color:cyan"> |-pooling_0: max</span>
# <span style="color:blue"> |-pooling_1: max</span>
# <span style="color:cyan"> |-pooling_2: max</span>
# <span style="color:blue"> |-pooling_3: avg</span>
# <span style="color:cyan"> |-tuner/bracket: 2</span>
# <span style="color:blue"> |-tuner/epochs: 2</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 1e2316042191e6f2f7e15af9dc08abe1</span>
# <span style="color:cyan"> |-Score: 0.6197999715805054</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_blocks: 3</span>
# <span style="color:blue"> |-dropout: 0.4</span>
# <span style="color:cyan"> |-filters_0: 160</span>
# <span style="color:blue"> |-filters_1: 256</span>
# <span style="color:cyan"> |-filters_2: 192</span>
# <span style="color:blue"> |-filters_3: 192</span>
# <span style="color:cyan"> |-hidden_size: 80</span>
# <span style="color:blue"> |-learning_rate: 0.0002699254383241978</span>
# <span style="color:cyan"> |-pooling_0: max</span>
# <span style="color:blue"> |-pooling_1: avg</span>
# <span style="color:cyan"> |-pooling_2: max</span>
# <span style="color:blue"> |-pooling_3: avg</span>
# <span style="color:cyan"> |-tuner/bracket: 2</span>
# <span style="color:blue"> |-tuner/epochs: 2</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: b8a20ef9b07e5c687528d845a950f0fe</span>
# <span style="color:cyan"> |-Score: 0.6172999739646912</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_blocks: 5</span>
# <span style="color:blue"> |-dropout: 0.2</span>
# <span style="color:cyan"> |-filters_0: 224</span>
# <span style="color:blue"> |-filters_1: 256</span>
# <span style="color:cyan"> |-filters_2: 128</span>
# <span style="color:blue"> |-filters_3: 224</span>
# <span style="color:cyan"> |-filters_4: 32</span>
# <span style="color:blue"> |-hidden_size: 40</span>
# <span style="color:cyan"> |-learning_rate: 0.008399696745250233</span>
# <span style="color:blue"> |-pooling_0: avg</span>
# <span style="color:cyan"> |-pooling_1: avg</span>
# <span style="color:blue"> |-pooling_2: max</span>
# <span style="color:cyan"> |-pooling_3: avg</span>
# <span style="color:blue"> |-pooling_4: avg</span>
# <span style="color:cyan"> |-tuner/bracket: 2</span>
# <span style="color:blue"> |-tuner/epochs: 2</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 7e1f0af665660fbe5040be2aa6789aa9</span>
# <span style="color:cyan"> |-Score: 0.6330000162124634</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_blocks: 3</span>
# <span style="color:blue"> |-dropout: 0.5</span>
# <span style="color:cyan"> |-filters_0: 96</span>
# <span style="color:blue"> |-filters_1: 96</span>
# <span style="color:cyan"> |-filters_2: 128</span>
# <span style="color:blue"> |-filters_3: 128</span>
# <span style="color:cyan"> |-filters_4: 224</span>
# <span style="color:blue"> |-hidden_size: 80</span>
# <span style="color:cyan"> |-learning_rate: 0.00022910740420359905</span>
# <span style="color:blue"> |-pooling_0: max</span>
# <span style="color:cyan"> |-pooling_1: avg</span>
# <span style="color:blue"> |-pooling_2: avg</span>
# <span style="color:cyan"> |-pooling_3: avg</span>
# <span style="color:blue"> |-pooling_4: max</span>
# <span style="color:cyan"> |-tuner/bracket: 2</span>
# <span style="color:blue"> |-tuner/epochs: 2</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 765f5fe6948bbda6f0f4d2b302be86bb</span>
# <span style="color:cyan"> |-Score: 0.6202999949455261</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_blocks: 4</span>
# <span style="color:blue"> |-dropout: 0.1</span>
# <span style="color:cyan"> |-filters_0: 64</span>
# <span style="color:blue"> |-filters_1: 64</span>
# <span style="color:cyan"> |-filters_2: 192</span>
# <span style="color:blue"> |-filters_3: 128</span>
# <span style="color:cyan"> |-filters_4: 224</span>
# <span style="color:blue"> |-hidden_size: 50</span>
# <span style="color:cyan"> |-learning_rate: 0.0005057140844109131</span>
# <span style="color:blue"> |-pooling_0: avg</span>
# <span style="color:cyan"> |-pooling_1: max</span>
# <span style="color:blue"> |-pooling_2: avg</span>
# <span style="color:cyan"> |-pooling_3: max</span>
# <span style="color:blue"> |-pooling_4: avg</span>
# <span style="color:cyan"> |-tuner/bracket: 2</span>
# <span style="color:blue"> |-tuner/epochs: 2</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: a89ecbf17064b92077722d4863dcf1e5</span>
# <span style="color:cyan"> |-Score: 0.6938999891281128</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_blocks: 4</span>
# <span style="color:blue"> |-dropout: 0.2</span>
# <span style="color:cyan"> |-filters_0: 96</span>
# <span style="color:blue"> |-filters_1: 96</span>
# <span style="color:cyan"> |-filters_2: 32</span>
# <span style="color:blue"> |-filters_3: 224</span>
# <span style="color:cyan"> |-filters_4: 160</span>
# <span style="color:blue"> |-hidden_size: 60</span>
# <span style="color:cyan"> |-learning_rate: 0.00019140142918669913</span>
# <span style="color:blue"> |-pooling_0: max</span>
# <span style="color:cyan"> |-pooling_1: max</span>
# <span style="color:blue"> |-pooling_2: max</span>
# <span style="color:cyan"> |-pooling_3: avg</span>
# <span style="color:blue"> |-pooling_4: max</span>
# <span style="color:cyan"> |-tuner/bracket: 2</span>
# <span style="color:blue"> |-tuner/epochs: 2</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: ede838582636c1c3e3222ebb611f2600</span>
# <span style="color:cyan"> |-Score: 0.6642000079154968</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_blocks: 4</span>
# <span style="color:blue"> |-dropout: 0.30000000000000004</span>
# <span style="color:cyan"> |-filters_0: 256</span>
# <span style="color:blue"> |-filters_1: 64</span>
# <span style="color:cyan"> |-filters_2: 64</span>
# <span style="color:blue"> |-filters_3: 256</span>
# <span style="color:cyan"> |-filters_4: 192</span>
# <span style="color:blue"> |-hidden_size: 70</span>
# <span style="color:cyan"> |-learning_rate: 0.00023747115131631685</span>
# <span style="color:blue"> |-pooling_0: avg</span>
# <span style="color:cyan"> |-pooling_1: avg</span>
# <span style="color:blue"> |-pooling_2: max</span>
# <span style="color:cyan"> |-pooling_3: avg</span>
# <span style="color:blue"> |-pooling_4: max</span>
# <span style="color:cyan"> |-tuner/bracket: 2</span>
# <span style="color:blue"> |-tuner/epochs: 2</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: fca3e19f4cc4d12f5e19c3669a8d19c9</span>
# <span style="color:cyan"> |-Score: 0.5185999870300293</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_blocks: 5</span>
# <span style="color:blue"> |-dropout: 0.2</span>
# <span style="color:cyan"> |-filters_0: 128</span>
# <span style="color:blue"> |-filters_1: 160</span>
# <span style="color:cyan"> |-filters_2: 32</span>
# <span style="color:blue"> |-filters_3: 128</span>
# <span style="color:cyan"> |-filters_4: 224</span>
# <span style="color:blue"> |-hidden_size: 40</span>
# <span style="color:cyan"> |-learning_rate: 0.0017896435437311782</span>
# <span style="color:blue"> |-pooling_0: max</span>
# <span style="color:cyan"> |-pooling_1: max</span>
# <span style="color:blue"> |-pooling_2: max</span>
# <span style="color:cyan"> |-pooling_3: max</span>
# <span style="color:blue"> |-pooling_4: max</span>
# <span style="color:cyan"> |-tuner/bracket: 2</span>
# <span style="color:blue"> |-tuner/epochs: 2</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 989a52b046482dacf13d4f7c62072d3a</span>
# <span style="color:cyan"> |-Score: 0.5285000205039978</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_blocks: 3</span>
# <span style="color:blue"> |-dropout: 0.4</span>
# <span style="color:cyan"> |-filters_0: 96</span>
# <span style="color:blue"> |-filters_1: 64</span>
# <span style="color:cyan"> |-filters_2: 160</span>
# <span style="color:blue"> |-filters_3: 96</span>
# <span style="color:cyan"> |-filters_4: 32</span>
# <span style="color:blue"> |-hidden_size: 100</span>
# <span style="color:cyan"> |-learning_rate: 0.005345318805375227</span>
# <span style="color:blue"> |-pooling_0: avg</span>
# <span style="color:cyan"> |-pooling_1: avg</span>
# <span style="color:blue"> |-pooling_2: max</span>
# <span style="color:cyan"> |-pooling_3: avg</span>
# <span style="color:blue"> |-pooling_4: max</span>
# <span style="color:cyan"> |-tuner/bracket: 2</span>
# <span style="color:blue"> |-tuner/epochs: 2</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 1bb0ee1ab98db11c92dde3d7a9680e88</span>
# <span style="color:cyan"> |-Score: 0.701200008392334</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-conv_blocks: 3</span>
# <span style="color:blue"> |-dropout: 0.4</span>
# <span style="color:cyan"> |-filters_0: 192</span>
# <span style="color:blue"> |-filters_1: 64</span>
# <span style="color:cyan"> |-filters_2: 128</span>
# <span style="color:blue"> |-filters_3: 160</span>
# <span style="color:cyan"> |-filters_4: 64</span>
# <span style="color:blue"> |-hidden_size: 80</span>
# <span style="color:cyan"> |-learning_rate: 0.0006648403575683647</span>
# <span style="color:blue"> |-pooling_0: max</span>
# <span style="color:cyan"> |-pooling_1: avg</span>
# <span style="color:blue"> |-pooling_2: max</span>
# <span style="color:cyan"> |-pooling_3: max</span>
# <span style="color:blue"> |-pooling_4: max</span>
# <span style="color:cyan"> |-tuner/bracket: 2</span>
# <span style="color:blue"> |-tuner/epochs: 2</span>
# <span style="color:cyan"> |-tuner/initial_epoch: 0</span>
# <span style="color:blue"> |-tuner/round: 0</span>
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5d798d199c37> in <module>
#       7              validation_data=test_ds,
#       8              epochs=10,
# ----> 9              callbacks=[tf.keras.callbacks.EarlyStopping(patience=1)])
#      10
#      11 best_model = tuner2.get_best_models(1)[0]
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\kerastuner\engine\base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     128
#     129             self.on_trial_begin(trial)
# --> 130             self.run_trial(trial, *fit_args, **fit_kwargs)
#     131             self.on_trial_end(trial)
#     132         self.on_search_end()
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\kerastuner\tuners\hyperband.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     385             fit_kwargs['epochs'] = hp.values['tuner/epochs']
#     386             fit_kwargs['initial_epoch'] = hp.values['tuner/initial_epoch']
# --> 387         super(Hyperband, self).run_trial(trial, *fit_args, **fit_kwargs)
#     388
#     389     def _build_model(self, hp):
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\kerastuner\engine\multi_execution_tuner.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#      94
#      95             model = self.hypermodel.build(trial.hyperparameters)
# ---> 96             history = model.fit(*fit_args, **copied_fit_kwargs)
#      97             for metric, epoch_values in history.history.items():
#      98                 if self.oracle.objective.direction == 'min':
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\util\nest.py in <listcomp>(.0)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in _non_none_constant_value(v)
#     128
#     129 def _non_none_constant_value(v):
# --> 130   constant_value = tensor_util.constant_value(v)
#     131   return constant_value if constant_value is not None else v
#     132
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\framework\tensor_util.py in constant_value(tensor, partial)
#     820   """
#     821   if isinstance(tensor, ops.EagerTensor):
# --> 822     return tensor.numpy()
#     823   if not is_tensor(tensor):
#     824     return tensor
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\framework\ops.py in numpy(self)
#     940     """
#     941     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 942     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     943     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     944
#
# c:\users\kuki\pycharmprojects\tensorflow-tutorial-kyu\venv\lib\site-packages\tensorflow_core\python\framework\ops.py in _numpy(self)
#     906     # pylint: disable=protected-access
#     907     try:
# --> 908       return self._numpy_internal()
#     909     except core._NotOkStatusException as e:
#     910       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
best_model = tuner2.get_best_models(1)[0]
best_hyperparameters = tuner2.get_best_hyperparameters(1)[0]
